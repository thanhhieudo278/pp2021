# %%
studentL = {}
def inst(id, name, dob):
    studentL[id] = [name, dob]
def NoS():
    global nos
    nos = int(input("Number of Students: "))
listSt = []
class Student():
    def __init__(self, id, name, dob):
        self.id = id
        self.name = name
        self.dob = dob
    
    def print_St(self):
        print("ID student : " + self.id)
        print("Name student : " + self.name)
        print("Dob student : " + self.dob)
    
def CreateList_St():
    for i in range(0,nos):
        listSt.append("s" + str(i))

def In_St():
    print("Enter Student Information: ")
    for i in range(0,nos):
        print("Student " + str(i+1))
        id  = input("Enter Student ID: ")
        name = input("Enter Student Name: ")
        DoB = input("Enter Student DoB: ")
        inst(id, name,DoB)
        listSt[i] = Student(id,name,DoB)

def print_St():
    print("All Students: ")
    for i in range(0,nos):
        print("Student " + str(i+1))
        listSt[i].print_St()

 
        
NoS()
CreateList_St()
In_St()
print_St()


courseL = {}
def inCo(id, name):
    courseL[id] = name   
def NoC():
    global noc
    noc = int(input("number of Course: "))
listC = []
class Course():
    def __init__(self, id, name):
        self.id = id
        self.name = name
        
    
    def print_C(self):
        print("ID course : " + self.id)
        print("Name course : " + self.name)
        
def CreateList_C():
    for i in range(0,noc):
        listC.append("s" + str(i))

def In_C():
    print("Enter Course Information: ")
    for i in range(0,noc):
        print("Course " + str(i+1))
        id = input("ID: ")
        name = input("Name : ")
        inCo(id, name)
        listC[i] = Course(id,name)

def print_C():
    print("ALL Courses")
    for i in range(0,noc):
        print("Course " + str(i+1))
        listC[i].print_C()

 
        
NoC()
CreateList_C()
In_C()
print_C()



class Mark():
    def __init__(self, id_s, id_c, mark):
        self.id_s = id_s
        self.id_c = id_c
        self.mark = mark
    def print_mark(self):
        print("ID student: " +self.id_s)
        print("ID course: " +self.id_c)
        print("mark: " +self.mark)
def input_Mark():
    id_s = input("Enter Student'ID to input Mark: ")
    if id_s in studentL:
        id_c = input("Enter Course'ID to input Mark: ")
        if id_c in courseL:
            mark = int(input("mark: "))
            listMark = Mark(id_s,id_c,mark)
            
def print_Mark():
    print("mark information: ")
    listMark.print_mark()

input_Mark()
print_Mark()
# Out:
# Number of Students: 1
# Enter Student Information:
# Student 1
# Enter Student ID: 1
# Enter Student Name: hh
# Enter Student DoB: 12
# All Students:
# Student 1
# ID student : 1
# Name student : hh
# Dob student : 12
# number of Course: 1
# Enter Course Information:
# Course 1
# ID: 1
# Name : tt
# ALL Courses
# Course 1
# ID course : 1
# Name course : tt
# Enter Student'ID to input Mark: 1
# Enter Course'ID to input Mark: 1
# mark: 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-ef5c0e86f039> in <module>
#     111
#     112 input_Mark()
# --> 113 listMark = Mark(id_s,id_c,mark)
#     114 print_Mark()
#
# NameError: name 'id_s' is not defined
